# %% [markdown]
# # The World's Happiness
# #### Tiffany Li
# #### August 4, 2023

# %% [markdown]
# ## Introduction

# %% [markdown]
# Different people have different purposes in life: some want to have a successful career, some want to be filthy rich, some want a family, but above everything, humans naturally want to be happy. This project explores the happiness of people from different countries and the some of the many variables that may contribute to one's happiness.

# %% [markdown]
# ### Data
#
# The datasets highlighted in this assignment aims to analyze the happiness of citizens in each country, focusing on different variables that may influence them. One dataset discusses the changes of these variables in each country over the years while the other dataset describes the 2022 happiness scores of each country, with the supporting variable scores.

# %% [markdown]
# ### Link
#
# This data is taken from the 2022 World Happiness Report at https://worldhappiness.report/ed/2022/.

# %% [markdown]
# ### Motivations
#
# I think one of the many things I’m interested in and enjoy analyzing is human behavior – why people think a certain way and/or how things may affect them. With Generation Z bringing a lot more awareness to mental health, it sparked a curiosity in me to think about our happiness and what factors may play a role. Is it dependent on our countries’ policies? Our cultural factors? What variables are there? With COVID-19 trampling our world in recent years, I’ve also thought a lot about how that has affected who we are as a society. I know I personally have been affected by this in more ways than one, so I was curious to see if the numbers reflect this as well, especially when it pertains to our happiness.

# %% [markdown]
# ### Research Questions
#
# For this assignment, I decided to compare the happiness variable factors of the United States, the country I reside in, with the highest ranked country in happiness, Finland. I was curious to know:
# * How does the happiness score vary between the two countries?
# * Which variables have major differences and what might be the cause of them?
#
# Due to COVID occurring in recent years, I also wanted to see if there was any major difference between the two countries (or even if COVID is reflected in the data of each individual country).

# %% [markdown]
# ## Methods

# %%
import pandas as pd
import matplotlib.pyplot as plt
Happiness_Report = 'HappinessReportCSV.csv'
Happiness_Score = 'HappinessScoreData.csv'
df1 = pd.read_csv(Happiness_Report)
df2 = pd.read_csv(Happiness_Score)

# %%
US_Score = df2[df2['Country'] == 'United States']
Fin_Score = df2[df2['Country'] == 'Finland']

# %%
countries = ['United States', 'Finland']

US_GDP = US_Score.iloc[0, 6]
US_SS = US_Score.iloc[0, 7]
US_HLE = US_Score.iloc[0, 8]
US_FLC = US_Score.iloc[0, 9]
US_Gen = US_Score.iloc[0, 10]
US_Corr = US_Score.iloc[0, 11]

Fin_GDP = Fin_Score.iloc[0, 6]
Fin_SS = Fin_Score.iloc[0, 7]
Fin_HLE = Fin_Score.iloc[0, 8]
Fin_FLC = Fin_Score.iloc[0, 9]
Fin_Gen = Fin_Score.iloc[0, 10]
Fin_Corr = Fin_Score.iloc[0, 11]

GDP = [US_GDP, Fin_GDP]
SS = [US_SS, Fin_SS]
HLE = [US_HLE, Fin_HLE]
FLC = [US_FLC, Fin_FLC]
Gen = [US_Gen, Fin_Gen]
Corr = [US_Corr, Fin_Corr]

x = range(len(countries))

plt.bar(x, GDP, label = 'Explained by GDP per Capita')
plt.bar(x, SS, bottom = GDP, label = 'Explained by Social Support')
plt.bar(x, HLE, bottom=[i + j for i, j in zip(GDP, SS)], label='Explained by Healthy Life Expectancy')
plt.bar(x, FLC, bottom=[i + j for i, j in zip(GDP, SS, HLE)], label='Explained by Freedom to make Life Choices')

plt.xlabel('Country')
plt.ylabel('Variable Values')
plt.title('Happiness Score of the US vs Finland')
plt.xticks(x, countries)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 29
#      27 plt.bar(x, SS, bottom = GDP, label = 'Explained by Social Support')
#      28 plt.bar(x, HLE, bottom=[i + j for i, j in zip(GDP, SS)], label='Explained by Healthy Life Expectancy')
# ---> 29 plt.bar(x, FLC, bottom=[i + j for i, j in zip(GDP, SS, HLE)], label='Explained by Freedom to make Life Choices')
#      31 plt.xlabel('Country')
#      32 plt.ylabel('Variable Values')
#
# Cell In[3], line 29, in <listcomp>(.0)
#      27 plt.bar(x, SS, bottom = GDP, label = 'Explained by Social Support')
#      28 plt.bar(x, HLE, bottom=[i + j for i, j in zip(GDP, SS)], label='Explained by Healthy Life Expectancy')
# ---> 29 plt.bar(x, FLC, bottom=[i + j for i, j in zip(GDP, SS, HLE)], label='Explained by Freedom to make Life Choices')
#      31 plt.xlabel('Country')
#      32 plt.ylabel('Variable Values')
#
# ...

# %%
US = df1[df1['Country name'] == 'United States']
Fin = df1[df1['Country name'] == 'Finland']

# %%
x1 = US['year']
x2 = Fin['year']
y1_Gen = US['Generosity']
y2_Gen = Fin['Generosity']

plt.plot(x1, y1_Gen, label='US', color='blue', marker='o')
plt.plot(x2, y2_Gen, label='Finland', color='red', marker='s')

plt.xlabel('Years')
plt.ylabel('Generosity')
plt.title('Generosity in US vs. Finland')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x1 = US['year']
x2 = Fin['year']
y1_HLE = US['Healthy life expectancy at birth']
y2_HLE = Fin['Healthy life expectancy at birth']

plt.plot(x1, y1_HLE, label='US', color='blue', marker='o')
plt.plot(x2, y2_HLE, label='Finland', color='red', marker='s')

plt.xlabel('Years')
plt.ylabel('Healthy Life Expectancy')
plt.title('Healthy Life Expectancy in US vs. Finland')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x1 = US['year']
x2 = Fin['year']
y1_Corr = US['Perceptions of corruption']
y2_Corr = Fin['Perceptions of corruption']

plt.plot(x1, y1_Corr, label='US', color='blue', marker='o')
plt.plot(x2, y2_Corr, label='Finland', color='red', marker='s')

plt.xlabel('Years')
plt.ylabel('Perceptions of Corruption')
plt.title('Perceptions of Corruption in US vs. Finland')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x1 = US['year']
x2 = Fin['year']
y1_Gov = US['Confidence in national government']
y2_Gov = Fin['Confidence in national government']

plt.plot(x1, y1_Gov, label='US', color='blue', marker='o')
plt.plot(x2, y2_Gov, label='Finland', color='red', marker='s')

plt.xlabel('Years')
plt.ylabel('Confidence in National Government')
plt.title('Confidence in National Government in US vs. Finland')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Results

# %% [markdown]
# ## Discussion

# %%
categories = ['Category A', 'Category B', 'Category C']
group1_values = [10, 15, 12]
group2_values = [8, 11, 9]
group3_values = [5, 7, 6]

# %%
# Set the width of the bars
bar_width = 0.6

# Create an array of positions for the bars
x = range(len(categories))

# Plot the bars for group1_values
plt.bar(x, group1_values, width=bar_width, label='Group 1')

# Plot the bars for group2_values on top of group1_values
plt.bar(x, group2_values, bottom=group1_values, width=bar_width, label='Group 2')

# Plot the bars for group3_values on top of group2_values
plt.bar(x, group3_values, bottom=[i + j for i, j in zip(group1_values, group2_values)],
        width=bar_width, label='Group 3')

# Customize the plot
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Stacked Bar Graph')
plt.xticks(x, categories)
plt.legend()

# Show the plot
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [3, 5, 7, 9, 11]
y2 = [2, 4, 6, 8, 10]
# Plot the first line graph
plt.plot(x, y1, label='Line 1', color='blue', marker='o')

# Plot the second line graph
plt.plot(x, y2, label='Line 2', color='red', marker='s')

# Customize the plot
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Two Line Graphs')
plt.legend()

# Show the plot
plt.show()
